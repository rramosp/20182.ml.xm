# %%
from sklearn.datasets import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image


def plot_2Ddata_with_boundary(predict,X,y):
    n = 200
    mins,maxs = np.min(X,axis=0), np.max(X,axis=0)
    mins -= np.abs(mins)*.2
    maxs += np.abs(maxs)*.2
    d0 = np.linspace(mins[0], maxs[0],n)
    d1 = np.linspace(mins[1], maxs[1],n)
    gd0,gd1 = np.meshgrid(d0,d1)
    D = np.hstack((gd0.reshape(-1,1), gd1.reshape(-1,1)))
    p = (predict(D)*1.).reshape((n,n))
    plt.contourf(gd0,gd1,p, levels=[-0.1,0.5], alpha=0.5, cmap=plt.cm.Greys)
    plt.scatter(X[y==0][:,0], X[y==0][:,1], c="blue")
    plt.scatter(X[y==1][:,0], X[y==1][:,1], c="red")
    
def visualize_tree(tree, feature_names):
    from sklearn.tree import export_graphviz
    with open("/tmp/dt.dot", 'w') as f:
        export_graphviz(tree, out_file=f, impurity=False, class_names=["blue", "red"],
                        feature_names=feature_names, label="none")

    # !dot -Tpng /tmp/dt.dot -o /tmp/dt.png
    
hasdot = !which dot
if len(hasdot)==0:
    print "Installing Graphviz for tree visualization"
    # !sudo apt-get update
    # !sudo apt-get install -y graphviz
# Out:
# Installing Graphviz for tree visualization
# Hit:1 http://co.archive.ubuntu.com/ubuntu artful InRelease
# Get:2 http://co.archive.ubuntu.com/ubuntu artful-updates InRelease [88.7 kB]
# Get:3 http://co.archive.ubuntu.com/ubuntu artful-backports InRelease [74.6 kB]
# Get:4 http://security.ubuntu.com/ubuntu artful-security InRelease [83.2 kB]
# Get:5 http://co.archive.ubuntu.com/ubuntu artful-updates/main i386 Packages [268 kB]
# Get:6 http://security.ubuntu.com/ubuntu artful-security/main i386 Packages [174 kB]
# Get:7 http://co.archive.ubuntu.com/ubuntu artful-updates/main amd64 Packages [272 kB]
# Get:8 http://co.archive.ubuntu.com/ubuntu artful-updates/main Translation-en [124 kB]
# Get:9 http://security.ubuntu.com/ubuntu artful-security/main amd64 Packages [176 kB]
# Get:10 http://co.archive.ubuntu.com/ubuntu artful-updates/restricted i386 Packages [2,188 B]
# Get:11 http://co.archive.ubuntu.com/ubuntu artful-updates/restricted amd64 Packages [2,200 B]
# Get:12 http://co.archive.ubuntu.com/ubuntu artful-updates/restricted Translation-en [1,284 B]
# Get:13 http://co.archive.ubuntu.com/ubuntu artful-updates/universe i386 Packages [123 kB]
# Get:14 http://security.ubuntu.com/ubuntu artful-security/main Translation-en [80.1 kB]
# Get:15 http://security.ubuntu.com/ubuntu artful-security/restricted amd64 Packages [2,200 B]
# Get:16 http://security.ubuntu.com/ubuntu artful-security/restricted i386 Packages [2,188 B]
# Get:17 http://security.ubuntu.com/ubuntu artful-security/restricted Translation-en [1,284 B]
# Get:18 http://security.ubuntu.com/ubuntu artful-security/universe i386 Packages [71.4 kB]
# Get:19 http://security.ubuntu.com/ubuntu artful-security/universe amd64 Packages [72.0 kB]
# Get:20 http://co.archive.ubuntu.com/ubuntu artful-updates/universe amd64 Packages [124 kB]
# Get:21 http://security.ubuntu.com/ubuntu artful-security/universe Translation-en [42.8 kB]
# Get:22 http://co.archive.ubuntu.com/ubuntu artful-updates/universe Translation-en [69.6 kB]
# Get:23 http://security.ubuntu.com/ubuntu artful-security/multiverse amd64 Packages [1,824 B]
# Get:24 http://security.ubuntu.com/ubuntu artful-security/multiverse i386 Packages [1,980 B]
# Get:25 http://security.ubuntu.com/ubuntu artful-security/multiverse Translation-en [1,124 B]
# Get:26 http://co.archive.ubuntu.com/ubuntu artful-updates/multiverse amd64 Packages [4,128 B]
# Get:27 http://co.archive.ubuntu.com/ubuntu artful-updates/multiverse i386 Packages [4,272 B]
# Get:28 http://co.archive.ubuntu.com/ubuntu artful-updates/multiverse Translation-en [2,264 B]
# Get:29 http://co.archive.ubuntu.com/ubuntu artful-backports/main i386 Packages [1,512 B]
# Get:30 http://co.archive.ubuntu.com/ubuntu artful-backports/main amd64 Packages [1,516 B]
# Get:31 http://co.archive.ubuntu.com/ubuntu artful-backports/main Translation-en [668 B]
# Get:32 http://co.archive.ubuntu.com/ubuntu artful-backports/universe i386 Packages [3,848 B]
# Get:33 http://co.archive.ubuntu.com/ubuntu artful-backports/universe amd64 Packages [4,076 B]
# Get:34 http://co.archive.ubuntu.com/ubuntu artful-backports/universe Translation-en [2,116 B]
# Fetched 1,883 kB in 2s (664 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation libcairo2
#   libcdt5 libcgraph6 libdatrie1 libfontconfig1 libgd3 libgraphite2-3 libgvc6
#   libgvpr2 libharfbuzz0b libjbig0 libjpeg-turbo8 libjpeg8 libltdl7
#   libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4
#   libpixman-1-0 libthai-data libthai0 libtiff5 libwebp6 libxaw7 libxcb-render0
#   libxcb-shm0 libxmu6 libxpm4 libxt6
# Suggested packages:
#   gsfonts graphviz-doc libgd-tools
# The following NEW packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation graphviz
#   libcairo2 libcdt5 libcgraph6 libdatrie1 libfontconfig1 libgd3 libgraphite2-3
#   libgvc6 libgvpr2 libharfbuzz0b libjbig0 libjpeg-turbo8 libjpeg8 libltdl7
#   libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4
#   libpixman-1-0 libthai-data libthai0 libtiff5 libwebp6 libxaw7 libxcb-render0
#   libxcb-shm0 libxmu6 libxpm4 libxt6
# 0 upgraded, 34 newly installed, 0 to remove and 136 not upgraded.
# Need to get 6,278 kB of archives.
# After this operation, 27.2 MB of additional disk space will be used.
# Get:1 http://co.archive.ubuntu.com/ubuntu artful/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:2 http://co.archive.ubuntu.com/ubuntu artful/main amd64 fontconfig-config all 2.11.94-0ubuntu2 [49.9 kB]
# Get:3 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libfontconfig1 amd64 2.11.94-0ubuntu2 [131 kB]
# Get:4 http://co.archive.ubuntu.com/ubuntu artful/main amd64 fontconfig amd64 2.11.94-0ubuntu2 [177 kB]
# Get:5 http://co.archive.ubuntu.com/ubuntu artful-updates/main amd64 libjpeg-turbo8 amd64 1.5.2-0ubuntu5.17.10.1 [110 kB]
# Get:6 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libjbig0 amd64 2.1-3.1 [26.6 kB]
# Get:7 http://co.archive.ubuntu.com/ubuntu artful/main amd64 fonts-liberation all 1:1.07.4-2 [822 kB]
# Get:8 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libcdt5 amd64 2.38.0-16ubuntu2 [19.5 kB]
# Get:9 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libcgraph6 amd64 2.38.0-16ubuntu2 [40.0 kB]
# Get:10 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libjpeg8 amd64 8c-2ubuntu8 [2,194 B]
# Get:11 http://co.archive.ubuntu.com/ubuntu artful-updates/main amd64 libtiff5 amd64 4.0.8-5ubuntu0.1 [150 kB]
# Get:12 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libwebp6 amd64 0.6.0-3 [181 kB]
# Get:13 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libxpm4 amd64 1:3.5.12-1 [34.0 kB]
# Get:14 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libgd3 amd64 2.2.5-3 [119 kB]
# Get:15 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libpixman-1-0 amd64 0.34.0-1 [230 kB]
# Get:16 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libxcb-render0 amd64 1.12-1ubuntu1 [14.8 kB]
# Get:17 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libxcb-shm0 amd64 1.12-1ubuntu1 [5,482 B]
# Get:18 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libcairo2 amd64 1.14.10-1ubuntu1 [558 kB]
# Get:19 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libltdl7 amd64 2.4.6-2 [38.8 kB]
# Get:20 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libthai-data all 0.1.26-3 [132 kB]
# Get:21 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libdatrie1 amd64 0.2.10-5 [17.6 kB]
# Get:22 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libthai0 amd64 0.1.26-3 [17.7 kB]
# Get:23 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libpango-1.0-0 amd64 1.40.12-1 [152 kB]
# Get:24 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libgraphite2-3 amd64 1.3.10-2 [78.3 kB]
# Get:25 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libharfbuzz0b amd64 1.4.2-1 [211 kB]
# Get:26 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libpangoft2-1.0-0 amd64 1.40.12-1 [33.2 kB]
# Get:27 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libpangocairo-1.0-0 amd64 1.40.12-1 [20.8 kB]
# Get:28 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libpathplan4 amd64 2.38.0-16ubuntu2 [22.6 kB]
# Get:29 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libgvc6 amd64 2.38.0-16ubuntu2 [587 kB]
# Get:30 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libgvpr2 amd64 2.38.0-16ubuntu2 [167 kB]
# Get:31 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libxt6 amd64 1:1.1.5-1 [160 kB]
# Get:32 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libxmu6 amd64 2:1.1.2-2 [46.0 kB]
# Get:33 http://co.archive.ubuntu.com/ubuntu artful/main amd64 libxaw7 amd64 2:1.0.13-1 [173 kB]
# Get:34 http://co.archive.ubuntu.com/ubuntu artful/main amd64 graphviz amd64 2.38.0-16ubuntu2 [710 kB]
# Fetched 6,278 kB in 16s (382 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 67103 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fontconfig-config.
# Preparing to unpack .../01-fontconfig-config_2.11.94-0ubuntu2_all.deb ...
# Unpacking fontconfig-config (2.11.94-0ubuntu2) ...
# Selecting previously unselected package libfontconfig1:amd64.
# Preparing to unpack .../02-libfontconfig1_2.11.94-0ubuntu2_amd64.deb ...
# Unpacking libfontconfig1:amd64 (2.11.94-0ubuntu2) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../03-fontconfig_2.11.94-0ubuntu2_amd64.deb ...
# Unpacking fontconfig (2.11.94-0ubuntu2) ...
# Selecting previously unselected package libjpeg-turbo8:amd64.
# Preparing to unpack .../04-libjpeg-turbo8_1.5.2-0ubuntu5.17.10.1_amd64.deb ...
# Unpacking libjpeg-turbo8:amd64 (1.5.2-0ubuntu5.17.10.1) ...
# Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../05-libjbig0_2.1-3.1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1) ...
# Selecting previously unselected package fonts-liberation.
# Preparing to unpack .../06-fonts-liberation_1%3a1.07.4-2_all.deb ...
# Unpacking fonts-liberation (1:1.07.4-2) ...
# Selecting previously unselected package libcdt5.
# Preparing to unpack .../07-libcdt5_2.38.0-16ubuntu2_amd64.deb ...
# Unpacking libcdt5 (2.38.0-16ubuntu2) ...
# Selecting previously unselected package libcgraph6.
# Preparing to unpack .../08-libcgraph6_2.38.0-16ubuntu2_amd64.deb ...
# Unpacking libcgraph6 (2.38.0-16ubuntu2) ...
# Selecting previously unselected package libjpeg8:amd64.
# Preparing to unpack .../09-libjpeg8_8c-2ubuntu8_amd64.deb ...
# Unpacking libjpeg8:amd64 (8c-2ubuntu8) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../10-libtiff5_4.0.8-5ubuntu0.1_amd64.deb ...
# Unpacking libtiff5:amd64 (4.0.8-5ubuntu0.1) ...
# Selecting previously unselected package libwebp6:amd64.
# Preparing to unpack .../11-libwebp6_0.6.0-3_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.0-3) ...
# Selecting previously unselected package libxpm4:amd64.
# Preparing to unpack .../12-libxpm4_1%3a3.5.12-1_amd64.deb ...
# Unpacking libxpm4:amd64 (1:3.5.12-1) ...
# Selecting previously unselected package libgd3:amd64.
# Preparing to unpack .../13-libgd3_2.2.5-3_amd64.deb ...
# Unpacking libgd3:amd64 (2.2.5-3) ...
# Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../14-libpixman-1-0_0.34.0-1_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.34.0-1) ...
# Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../15-libxcb-render0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../16-libxcb-shm0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../17-libcairo2_1.14.10-1ubuntu1_amd64.deb ...
# Unpacking libcairo2:amd64 (1.14.10-1ubuntu1) ...
# Selecting previously unselected package libltdl7:amd64.
# Preparing to unpack .../18-libltdl7_2.4.6-2_amd64.deb ...
# Unpacking libltdl7:amd64 (2.4.6-2) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../19-libthai-data_0.1.26-3_all.deb ...
# Unpacking libthai-data (0.1.26-3) ...
# Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../20-libdatrie1_0.2.10-5_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.10-5) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../21-libthai0_0.1.26-3_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.26-3) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../22-libpango-1.0-0_1.40.12-1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.40.12-1) ...
# Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../23-libgraphite2-3_1.3.10-2_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.10-2) ...
# Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../24-libharfbuzz0b_1.4.2-1_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (1.4.2-1) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../25-libpangoft2-1.0-0_1.40.12-1_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.40.12-1) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../26-libpangocairo-1.0-0_1.40.12-1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.40.12-1) ...
# Selecting previously unselected package libpathplan4.
# Preparing to unpack .../27-libpathplan4_2.38.0-16ubuntu2_amd64.deb ...
# Unpacking libpathplan4 (2.38.0-16ubuntu2) ...
# Selecting previously unselected package libgvc6.
# Preparing to unpack .../28-libgvc6_2.38.0-16ubuntu2_amd64.deb ...
# Unpacking libgvc6 (2.38.0-16ubuntu2) ...
# Selecting previously unselected package libgvpr2.
# Preparing to unpack .../29-libgvpr2_2.38.0-16ubuntu2_amd64.deb ...
# Unpacking libgvpr2 (2.38.0-16ubuntu2) ...
# Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../30-libxt6_1%3a1.1.5-1_amd64.deb ...
# Unpacking libxt6:amd64 (1:1.1.5-1) ...
# Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../31-libxmu6_2%3a1.1.2-2_amd64.deb ...
# Unpacking libxmu6:amd64 (2:1.1.2-2) ...
# Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../32-libxaw7_2%3a1.0.13-1_amd64.deb ...
# Unpacking libxaw7:amd64 (2:1.0.13-1) ...
# Selecting previously unselected package graphviz.
# Preparing to unpack .../33-graphviz_2.38.0-16ubuntu2_amd64.deb ...
# Unpacking graphviz (2.38.0-16ubuntu2) ...
# Setting up libpathplan4 (2.38.0-16ubuntu2) ...
# Setting up libxcb-render0:amd64 (1.12-1ubuntu1) ...
# Setting up libjbig0:amd64 (2.1-3.1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libdatrie1:amd64 (0.2.10-5) ...
# Setting up libjpeg-turbo8:amd64 (1.5.2-0ubuntu5.17.10.1) ...
# Setting up fonts-liberation (1:1.07.4-2) ...
# Setting up libgraphite2-3:amd64 (1.3.10-2) ...
# Setting up libpixman-1-0:amd64 (0.34.0-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2) ...
# Setting up libltdl7:amd64 (2.4.6-2) ...
# Setting up libxcb-shm0:amd64 (1.12-1ubuntu1) ...
# Setting up libxpm4:amd64 (1:3.5.12-1) ...
# Setting up libxt6:amd64 (1:1.1.5-1) ...
# Processing triggers for man-db (2.7.6.1-2) ...
# Setting up libthai-data (0.1.26-3) ...
# Setting up libcdt5 (2.38.0-16ubuntu2) ...
# Setting up libcgraph6 (2.38.0-16ubuntu2) ...
# Setting up libwebp6:amd64 (0.6.0-3) ...
# Setting up libjpeg8:amd64 (8c-2ubuntu8) ...
# Setting up fontconfig-config (2.11.94-0ubuntu2) ...
# Setting up libgvpr2 (2.38.0-16ubuntu2) ...
# Setting up libharfbuzz0b:amd64 (1.4.2-1) ...
# Setting up libtiff5:amd64 (4.0.8-5ubuntu0.1) ...
# Setting up libthai0:amd64 (0.1.26-3) ...
# Setting up libxmu6:amd64 (2:1.1.2-2) ...
# Setting up libxaw7:amd64 (2:1.0.13-1) ...
# Setting up libfontconfig1:amd64 (2.11.94-0ubuntu2) ...
# Setting up libgd3:amd64 (2.2.5-3) ...
# Setting up fontconfig (2.11.94-0ubuntu2) ...
# Regenerating fonts cache... done.
# Setting up libcairo2:amd64 (1.14.10-1ubuntu1) ...
# Setting up libpango-1.0-0:amd64 (1.40.12-1) ...
# Setting up libpangoft2-1.0-0:amd64 (1.40.12-1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.40.12-1) ...
# Setting up libgvc6 (2.38.0-16ubuntu2) ...
# Setting up graphviz (2.38.0-16ubuntu2) ...
# Processing triggers for libc-bin (2.26-0ubuntu2) ...

# %% [markdown]
# ## Observa cómo funciona un árbol de decisión
#
# cambia el parámetro `max_deph` a 1, a 3 o a más y observa el árbol de decisión que se genera

# %%
from sklearn.tree import DecisionTreeClassifier
X,y = make_moons(400, noise=0.1)
dt = DecisionTreeClassifier(max_depth=2); dt.fit(X,y)
plot_2Ddata_with_boundary(dt.predict, X,y)
plt.xlabel("col1"); plt.ylabel("col2");

# %%
visualize_tree(dt, ["col1", "col2"])
Image("/tmp/dt.png", width=300)

# %% [markdown]
# ### Observa las fronteras de clasificación de
#
# - DecisionTree con max_depth=1
# - LogisticRegression
# - SVM polinomial de grado 2
#
# y observa también los scores respectivos

# %%
X,y = make_moons(400, noise=0.1)
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.cross_validation import cross_val_score

dt = DecisionTreeClassifier(max_depth=1); dt.fit(X,y)
lr = LogisticRegression(); lr.fit(X,y)
sv = SVC(kernel="poly", degree=2); sv.fit(X,y)
print "decision tree      ", np.mean(cross_val_score(dt, X,y, cv=10))
print "logistic regression", np.mean(cross_val_score(lr, X,y, cv=10))
print "poly svm degree 2  ", np.mean(cross_val_score(sv, X,y, cv=10))
plot_2Ddata_with_boundary(dt.predict, X,y)
plot_2Ddata_with_boundary(lr.predict, X,y)
plot_2Ddata_with_boundary(sv.predict, X,y)
# Out:
# /opt/miniconda/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# decision tree       0.8299999999999998
# logistic regression 0.8825
# poly svm degree 2   0.775

# %% [markdown]
# ### Clasificador combinado por votación

# %%
class VotingClassifier:
    
    def __init__(self):
        self._estimators = [DecisionTreeClassifier(), LogisticRegression(), SVC(kernel="poly", degree=2)]
        
    def fit(self, X,y):
        for estimator in self._estimators:
            estimator.fit(X,y)
            
    def predict(self, X):
        preds = np.zeros(X.shape[0])
        for estimator in self._estimators:
            preds += estimator.predict(X)
            
        preds = (preds>(len(self._estimators)/2.)).astype(int)
        return preds
    
    def score(self, X,y):
        return np.sum(self.predict(X)==y)*1./len(X)
    
    def get_params(self, deep=None):
        return dict()

# %%
vc = VotingClassifier()
vc.fit(X,y)
print "ensemble score", np.mean(cross_val_score(vc, X,y, cv=10))
plot_2Ddata_with_boundary(vc.predict, X,y)
# Out:
# ensemble score 0.9325000000000001
